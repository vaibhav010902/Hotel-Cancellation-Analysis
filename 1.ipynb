# %%
import numpy as np
import pandas as pd
file = pd.read_csv("hotel_bookings.csv")

# %%
file.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
file.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
file.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
column = ['lead_time','arrival_date_week_number','arrival_date_day_of_month','stays_in_weekend_nights','stays_in_week_nights','distribution_channel','meal','is_repeated_guest','previous_cancellations','previous_bookings_not_canceled','booking_changes','deposit_type','company','agent','days_in_waiting_list','adr','required_car_parking_spaces','total_of_special_requests']
file.drop(columns=column,inplace=True)
file.head()
# Out:
#           hotel  is_canceled  arrival_date_year arrival_date_month  adults  \
# 0  Resort Hotel            0               2015               July       2
# 1  Resort Hotel            0               2015               July       2
# 2  Resort Hotel            0               2015               July       1
# 3  Resort Hotel            0               2015               July       1
# 4  Resort Hotel            0               2015               July       2
#
#    children  babies country market_segment reserved_room_type  \
# 0       0.0       0     PRT         Direct                  C
# 1       0.0       0     PRT         Direct                  C
# 2       0.0       0     GBR         Direct                  A
# 3       0.0       0     GBR      Corporate                  A
# 4       0.0       0     GBR      Online TA                  A
#
#   assigned_room_type customer_type reservation_status reservation_status_date
# ...

# %%
file.isna().sum()
# Out:
# hotel                        0
# is_canceled                  0
# arrival_date_year            0
# arrival_date_month           0
# adults                       0
# children                     4
# babies                       0
# country                    488
# market_segment               0
# reserved_room_type           0
# assigned_room_type           0
# customer_type                0
# reservation_status           0
# reservation_status_date      0
# dtype: int64

# %%
file.children = file.children.replace(['NA',np.nan],0)
file.country = file.country.replace(np.nan,'Unknown')

# %%
file.isna().sum()
# Out:
# hotel                      0
# is_canceled                0
# arrival_date_year          0
# arrival_date_month         0
# adults                     0
# children                   0
# babies                     0
# country                    0
# market_segment             0
# reserved_room_type         0
# assigned_room_type         0
# customer_type              0
# reservation_status         0
# reservation_status_date    0
# dtype: int64

# %%
file['guest_type'] = ""
for index, (i, j, k) in enumerate(zip(file.adults, file.children, file.babies)):
    if i == 1 and j == 0 and k == 0:
        file.at[index, 'guest_type'] = "single"
    elif i == 2 and j == 0 and k == 0:
        file.at[index, 'guest_type'] = "couple"
    elif i > 1 and j > 0 and k > 0:
        file.at[index, 'guest_type'] = "family"
    else:
        file.at[index, 'guest_type'] = "family"

# %%
file.head()
# Out:
#           hotel  is_canceled  arrival_date_year arrival_date_month  adults  \
# 0  Resort Hotel            0               2015               July       2
# 1  Resort Hotel            0               2015               July       2
# 2  Resort Hotel            0               2015               July       1
# 3  Resort Hotel            0               2015               July       1
# 4  Resort Hotel            0               2015               July       2
#
#    children  babies country market_segment reserved_room_type  \
# 0       0.0       0     PRT         Direct                  C
# 1       0.0       0     PRT         Direct                  C
# 2       0.0       0     GBR         Direct                  A
# 3       0.0       0     GBR      Corporate                  A
# 4       0.0       0     GBR      Online TA                  A
#
#   assigned_room_type customer_type reservation_status reservation_status_date  \
# ...

# %%
file['room_status'] = ""
for index, (i,j) in enumerate(zip(file.reserved_room_type,file.assigned_room_type)):
    if(i==j):
        file.at[index,'room_status'] = "Desired"
    else:
        file.at[index,'room_status'] = "Undesired"

# %%
file['no._of_guest']=""
for index, (i,j,k) in  enumerate(zip(file.adults, file.children, file.babies)):
    file.at[index, 'no._of_guest'] = i+j+k

# %%
file.head()
# Out:
#           hotel  is_canceled  arrival_date_year arrival_date_month  adults  \
# 0  Resort Hotel            0               2015               July       2
# 1  Resort Hotel            0               2015               July       2
# 2  Resort Hotel            0               2015               July       1
# 3  Resort Hotel            0               2015               July       1
# 4  Resort Hotel            0               2015               July       2
#
#    children  babies country market_segment reserved_room_type  \
# 0       0.0       0     PRT         Direct                  C
# 1       0.0       0     PRT         Direct                  C
# 2       0.0       0     GBR         Direct                  A
# 3       0.0       0     GBR      Corporate                  A
# 4       0.0       0     GBR      Online TA                  A
#
#   assigned_room_type customer_type reservation_status reservation_status_date  \
# ...

# %%
file.isna().sum()
# Out:
# hotel                      0
# is_canceled                0
# arrival_date_year          0
# arrival_date_month         0
# adults                     0
# children                   0
# babies                     0
# country                    0
# market_segment             0
# reserved_room_type         0
# assigned_room_type         0
# customer_type              0
# reservation_status         0
# reservation_status_date    0
# guest_type                 0
# room_status                0
# no._of_guest               0
# dtype: int64

# %%
file.to_csv("updated_hotel_bookings.csv",index=False)
